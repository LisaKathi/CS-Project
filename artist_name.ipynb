# %%
# importing pandas and defining the cleaned dataset as df
import pandas as pd
df = pd.read_csv("./cleaned.csv")
df
# Out:
#            artist_name  year_artist_born   age  length  width  height  \
# 0           Etel Adnan            1925.0  96.0    81.0   65.0     1.0
# 1         Hilary Pecis            1979.0  42.0   106.9   76.3     1.0
# 2         Avery Singer            1987.0  34.0    76.2   98.5     1.0
# 3     Flora Yukhnovich            1990.0  31.0   169.5  220.0     1.0
# 4          Salman Toor            1983.0  38.0    99.5   80.0     1.0
# ...                ...               ...   ...     ...    ...     ...
# 4153         Fred Deux            1924.0  91.0    59.5   83.0     1.0
# 4154         Fred Deux            1924.0  91.0    71.0  101.0     1.0
# 4155         Fred Deux            1924.0  91.0    73.0  102.0     1.0
# 4156         Fred Deux            1924.0  91.0    46.5   17.5     1.0
# 4157         Fred Deux            1924.0  91.0    30.0   47.5     1.0
#
#       year_of_work  age_at_work  lower_est_USD  upper_est_USD  sold_in_USD  \
# 0           1973.0         48.0       74930.94       99907.92    440593.93
# 1           2019.0         40.0       62442.45       87419.43    251767.96
# 2           2016.0         29.0      187327.35      249769.80    314709.95
# 3           2020.0         30.0       74930.94       99907.92   2814281.22
# 4           2018.0         35.0      124884.90      187327.35    361916.44
# ...            ...          ...            ...            ...          ...
# 4153        1960.0         36.0         857.52        1286.28      6752.97
# 4154        1959.0         35.0        1071.90        2143.80      4727.08
# 4155        1959.0         35.0        1071.90        2143.80      6752.97
# 4156        1959.0         35.0        1607.85        2143.80      5672.49
# 4157        1959.0         35.0        2143.80        3215.70      6752.97
#
#       Material_Category  act_area  posthumous_combined
# 0                     1   5265.00                    0
# 1                     1   8156.47                    0
# 2                     1   7505.70                    0
# 3                     1  37290.00                    0
# 4                     1   7960.00                    0
# ...                 ...       ...                  ...
# 4153                  7   4938.50                    1
# 4154                  7   7171.00                    1
# 4155                  7   7446.00                    1
# 4156                 10    813.75                    1
# 4157                 10   1425.00                    1
#
# [4158 rows x 14 columns]

# %%
# creating a new column by calculating the average of the lower and upper estimate value
df["average_est_USD"] = ((df["lower_est_USD"] + df["upper_est_USD"]) / 2 )
df
# Out:
#            artist_name  year_artist_born   age  length  width  height  \
# 0           Etel Adnan            1925.0  96.0    81.0   65.0     1.0
# 1         Hilary Pecis            1979.0  42.0   106.9   76.3     1.0
# 2         Avery Singer            1987.0  34.0    76.2   98.5     1.0
# 3     Flora Yukhnovich            1990.0  31.0   169.5  220.0     1.0
# 4          Salman Toor            1983.0  38.0    99.5   80.0     1.0
# ...                ...               ...   ...     ...    ...     ...
# 4153         Fred Deux            1924.0  91.0    59.5   83.0     1.0
# 4154         Fred Deux            1924.0  91.0    71.0  101.0     1.0
# 4155         Fred Deux            1924.0  91.0    73.0  102.0     1.0
# 4156         Fred Deux            1924.0  91.0    46.5   17.5     1.0
# 4157         Fred Deux            1924.0  91.0    30.0   47.5     1.0
#
#       year_of_work  age_at_work  lower_est_USD  upper_est_USD  sold_in_USD  \
# 0           1973.0         48.0       74930.94       99907.92    440593.93
# 1           2019.0         40.0       62442.45       87419.43    251767.96
# 2           2016.0         29.0      187327.35      249769.80    314709.95
# 3           2020.0         30.0       74930.94       99907.92   2814281.22
# 4           2018.0         35.0      124884.90      187327.35    361916.44
# ...            ...          ...            ...            ...          ...
# 4153        1960.0         36.0         857.52        1286.28      6752.97
# 4154        1959.0         35.0        1071.90        2143.80      4727.08
# 4155        1959.0         35.0        1071.90        2143.80      6752.97
# 4156        1959.0         35.0        1607.85        2143.80      5672.49
# 4157        1959.0         35.0        2143.80        3215.70      6752.97
#
#       Material_Category  act_area  posthumous_combined  average_est_USD
# 0                     1   5265.00                    0        87419.430
# 1                     1   8156.47                    0        74930.940
# 2                     1   7505.70                    0       218548.575
# 3                     1  37290.00                    0        87419.430
# 4                     1   7960.00                    0       156106.125
# ...                 ...       ...                  ...              ...
# 4153                  7   4938.50                    1         1071.900
# 4154                  7   7171.00                    1         1607.850
# 4155                  7   7446.00                    1         1607.850
# 4156                 10    813.75                    1         1875.825
# 4157                 10   1425.00                    1         2679.750
#
# [4158 rows x 15 columns]

# %%
# using groupby to calculate the average estimation value of all artworks for each artist
# this is done to capture the differences between artists since we cannot use the column "artist_name" since it is categorical information
grouped = df.groupby("artist_name").agg({'average_est_USD': ['mean', 'count']}).round(2)
grouped
# Out:
#                             average_est_USD
#                                        mean count
# artist_name
# A. R. Penck                        21549.61     3
# A.R. Penck and Frank Wollny        12488.49     1
# Aaron Bobrow                        1873.28     1
# Aaron Fowler                       21500.00     1
# Aaron Garber-Maikovska             25000.00     1
# ...                                     ...   ...
# Édouard Brandon                     2500.00     1
# Émile Bernard                      50000.00     1
# Émile Othon Friesz                 15305.31     2
# Étienne Le Hongre                 214380.00     1
# Öyvind Fahlström                   12500.00     1
#
# [1776 rows x 2 columns]

# %%
# finding the values for the 10th, 20th, 30th, 40th, 50th, 60th, 70th, 80th and 90th percentile
import numpy as np
percentile_values = np.percentile(grouped["average_est_USD"]["mean"], [10, 20, 30, 40, 50, 60, 70, 80, 90])
percentile_values
# Out:
# array([  2497.7  ,   4762.03 ,   7493.1  ,  12488.49 ,  18112.915,
#         29072.84 ,  47234.355,  91111.5  , 254945.94 ])

# %%
# using n.digitize to assign bins
rank = np.digitize(grouped["average_est_USD"]["mean"], bins=percentile_values, right=True) 
# got the idea to use .digitize from ChatGPT to improve my prior code
# the prior code consisted of a loop that checked if i <= than each of the percentile_values and > than the last percentile value
# then it appended the according rank to the rank list

# making sure the ranks start from 1 instead of 0
rank += 1

# changing the array to a list
rank_list = rank.tolist()
rank_list
# Out:
# [6,
#  4,
#  1,
#  6,
#  6,
#  3,
#  7,
#  6,
#  7,
#  10,
#  2,
#  4,
#  6,
#  10,
#  10,
#  1,
#  10,
#  7,
#  9,
#  9,
#  9,
#  1,
#  3,
#  2,
#  7,
#  2,
#  1,
#  3,
#  2,
#  1,
#  3,
#  8,
#  7,
#  8,
#  2,
#  8,
#  3,
#  6,
#  8,
#  6,
#  7,
#  7,
#  8,
#  10,
#  10,
#  7,
#  6,
#  6,
#  2,
#  1,
#  3,
#  6,
#  7,
#  10,
#  2,
#  2,
#  9,
#  7,
#  3,
#  10,
#  3,
#  7,
#  4,
#  5,
#  7,
#  1,
#  10,
#  4,
#  5,
#  6,
#  4,
#  4,
#  3,
#  8,
#  1,
#  4,
#  5,
#  3,
#  3,
#  2,
#  8,
#  10,
#  8,
#  10,
#  7,
#  5,
#  10,
#  5,
#  4,
#  4,
#  7,
#  8,
#  8,
#  1,
#  4,
#  10,
#  8,
#  10,
#  8,
#  1,
#  2,
#  10,
#  3,
#  2,
#  6,
#  3,
#  4,
#  9,
#  8,
#  8,
#  8,
#  7,
#  6,
#  2,
#  7,
#  2,
#  6,
#  10,
#  8,
#  7,
#  4,
#  6,
#  1,
#  2,
#  10,
#  2,
#  2,
#  5,
#  5,
#  8,
#  5,
#  7,
#  6,
#  2,
#  10,
#  7,
#  1,
#  1,
#  3,
#  6,
#  5,
#  7,
#  9,
#  5,
#  10,
#  6,
#  1,
#  4,
#  9,
#  9,
#  9,
#  1,
#  4,
#  5,
#  3,
#  8,
#  2,
#  8,
#  6,
#  7,
#  8,
#  9,
#  9,
#  7,
#  8,
#  3,
#  1,
#  7,
#  6,
#  3,
#  4,
#  9,
#  6,
#  7,
#  1,
#  1,
#  6,
#  6,
#  4,
#  6,
#  1,
#  2,
#  7,
#  9,
#  6,
#  10,
#  2,
#  9,
#  1,
#  8,
#  7,
#  6,
#  2,
#  10,
#  10,
#  9,
#  9,
#  2,
#  4,
#  9,
#  3,
#  2,
#  10,
#  7,
#  2,
#  9,
#  6,
#  10,
#  1,
#  8,
#  3,
#  9,
#  2,
#  7,
#  2,
#  1,
#  4,
#  4,
#  2,
#  4,
#  4,
#  5,
#  3,
#  1,
#  2,
#  5,
#  2,
#  4,
#  7,
#  8,
#  2,
#  4,
#  4,
#  4,
#  7,
#  3,
#  3,
#  8,
#  10,
#  10,
#  10,
#  1,
#  3,
#  5,
#  7,
#  2,
#  2,
#  9,
#  4,
#  4,
#  1,
#  10,
#  2,
#  9,
#  1,
#  7,
#  5,
#  7,
#  3,
#  9,
#  2,
#  9,
#  7,
#  4,
#  3,
#  7,
#  10,
#  3,
#  5,
#  3,
#  7,
#  1,
#  8,
#  4,
#  6,
#  8,
#  10,
#  1,
#  10,
#  6,
#  3,
#  3,
#  5,
#  8,
#  3,
#  8,
#  3,
#  8,
#  9,
#  4,
#  5,
#  7,
#  3,
#  10,
#  2,
#  3,
#  10,
#  7,
#  6,
#  9,
#  9,
#  2,
#  6,
#  3,
#  8,
#  6,
#  8,
#  10,
#  10,
#  8,
#  5,
#  8,
#  2,
#  4,
#  8,
#  8,
#  8,
#  2,
#  9,
#  10,
#  4,
#  6,
#  5,
#  1,
#  10,
#  1,
#  2,
#  6,
#  3,
#  6,
#  3,
#  8,
#  1,
#  4,
#  4,
#  1,
#  7,
#  7,
#  8,
#  10,
#  10,
#  7,
#  4,
#  6,
#  4,
#  5,
#  2,
#  7,
#  1,
#  8,
#  9,
#  4,
#  7,
#  1,
#  2,
#  10,
#  4,
#  3,
#  6,
#  9,
#  1,
#  8,
#  1,
#  1,
#  3,
#  8,
#  10,
#  5,
#  5,
#  4,
#  7,
#  6,
#  1,
#  3,
#  3,
#  1,
#  2,
#  10,
#  6,
#  4,
#  8,
#  4,
#  7,
#  5,
#  1,
#  2,
#  7,
#  6,
#  10,
#  3,
#  5,
#  9,
#  1,
#  2,
#  3,
#  3,
#  1,
#  7,
#  7,
#  5,
#  4,
#  8,
#  4,
#  2,
#  5,
#  3,
#  10,
#  3,
#  3,
#  9,
#  6,
#  2,
#  6,
#  1,
#  3,
#  6,
#  3,
#  2,
#  2,
#  6,
#  10,
#  4,
#  8,
#  10,
#  8,
#  4,
#  1,
#  8,
#  5,
#  4,
#  9,
#  6,
#  8,
#  3,
#  3,
#  7,
#  10,
#  5,
#  8,
#  8,
#  7,
#  3,
#  10,
#  5,
#  8,
#  10,
#  6,
#  5,
#  1,
#  10,
#  4,
#  4,
#  5,
#  4,
#  6,
#  7,
#  1,
#  2,
#  6,
#  10,
#  4,
#  4,
#  1,
#  6,
#  1,
#  3,
#  8,
#  4,
#  2,
#  2,
#  1,
#  10,
#  6,
#  6,
#  5,
#  7,
#  8,
#  4,
#  2,
#  7,
#  9,
#  9,
#  1,
#  9,
#  5,
#  2,
#  3,
#  1,
#  4,
#  7,
#  2,
#  4,
#  4,
#  4,
#  6,
#  5,
#  3,
#  3,
#  7,
#  6,
#  2,
#  10,
#  2,
#  6,
#  1,
#  10,
#  9,
#  3,
#  7,
#  10,
#  9,
#  9,
#  10,
#  7,
#  8,
#  8,
#  4,
#  2,
#  4,
#  4,
#  4,
#  3,
#  9,
#  7,
#  3,
#  3,
#  9,
#  5,
#  7,
#  8,
#  4,
#  10,
#  1,
#  4,
#  10,
#  8,
#  3,
#  9,
#  4,
#  1,
#  9,
#  5,
#  3,
#  2,
#  2,
#  8,
#  9,
#  5,
#  4,
#  1,
#  9,
#  9,
#  7,
#  3,
#  1,
#  4,
#  4,
#  9,
#  5,
#  2,
#  10,
#  4,
#  10,
#  3,
#  3,
#  6,
#  9,
#  9,
#  8,
#  8,
#  2,
#  4,
#  2,
#  7,
#  10,
#  4,
#  7,
#  8,
#  2,
#  10,
#  7,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  4,
#  10,
#  5,
#  6,
#  4,
#  5,
#  1,
#  7,
#  1,
#  10,
#  5,
#  5,
#  8,
#  2,
#  10,
#  3,
#  3,
#  4,
#  7,
#  10,
#  5,
#  4,
#  7,
#  8,
#  2,
#  1,
#  5,
#  5,
#  10,
#  9,
#  2,
#  1,
#  4,
#  7,
#  3,
#  1,
#  8,
#  9,
#  8,
#  5,
#  5,
#  10,
#  1,
#  2,
#  4,
#  3,
#  3,
#  6,
#  8,
#  9,
#  7,
#  5,
#  8,
#  8,
#  3,
#  9,
#  3,
#  1,
#  8,
#  7,
#  6,
#  6,
#  1,
#  9,
#  10,
#  3,
#  7,
#  3,
#  3,
#  6,
#  2,
#  5,
#  6,
#  1,
#  2,
#  8,
#  9,
#  1,
#  7,
#  10,
#  4,
#  8,
#  10,
#  8,
#  8,
#  7,
#  10,
#  3,
#  10,
#  2,
#  5,
#  3,
#  1,
#  10,
#  3,
#  9,
#  9,
#  10,
#  3,
#  4,
#  5,
#  5,
#  1,
#  10,
#  7,
#  2,
#  10,
#  9,
#  2,
#  6,
#  9,
#  5,
#  2,
#  5,
#  7,
#  5,
#  4,
#  3,
#  1,
#  8,
#  3,
#  8,
#  7,
#  7,
#  8,
#  1,
#  2,
#  8,
#  1,
#  7,
#  9,
#  5,
#  5,
#  9,
#  9,
#  8,
#  8,
#  4,
#  5,
#  4,
#  3,
#  8,
#  2,
#  7,
#  1,
#  4,
#  8,
#  8,
#  1,
#  5,
#  9,
#  5,
#  5,
#  6,
#  7,
#  1,
#  10,
#  6,
#  10,
#  4,
#  8,
#  8,
#  2,
#  9,
#  1,
#  9,
#  4,
#  2,
#  8,
#  2,
#  9,
#  1,
#  1,
#  7,
#  6,
#  9,
#  7,
#  1,
#  1,
#  2,
#  6,
#  5,
#  5,
#  4,
#  9,
#  4,
#  4,
#  2,
#  2,
#  1,
#  1,
#  6,
#  10,
#  4,
#  8,
#  7,
#  8,
#  5,
#  2,
#  3,
#  7,
#  4,
#  9,
#  8,
#  6,
#  7,
#  7,
#  6,
#  6,
#  3,
#  6,
#  8,
#  10,
#  6,
#  9,
#  3,
#  5,
#  8,
#  3,
#  1,
#  5,
#  8,
#  4,
#  8,
#  4,
#  7,
#  8,
#  10,
#  9,
#  5,
#  7,
#  2,
#  1,
#  8,
#  10,
#  7,
#  9,
#  2,
#  5,
#  4,
#  10,
#  10,
#  9,
#  4,
#  1,
#  2,
#  6,
#  4,
#  3,
#  3,
#  10,
#  10,
#  10,
#  9,
#  8,
#  9,
#  3,
#  7,
#  5,
#  8,
#  6,
#  1,
#  3,
#  3,
#  5,
#  9,
#  1,
#  1,
#  7,
#  1,
#  1,
#  8,
#  4,
#  4,
#  4,
#  6,
#  8,
#  3,
#  3,
#  4,
#  6,
#  9,
#  9,
#  2,
#  7,
#  3,
#  5,
#  1,
#  4,
#  1,
#  1,
#  2,
#  1,
#  5,
#  7,
#  5,
#  7,
#  4,
#  3,
#  5,
#  3,
#  6,
#  5,
#  6,
#  10,
#  2,
#  7,
#  4,
#  3,
#  10,
#  9,
#  2,
#  1,
#  5,
#  7,
#  5,
#  1,
#  1,
#  3,
#  7,
#  5,
#  5,
#  9,
#  9,
#  6,
#  6,
#  5,
#  3,
#  6,
#  8,
#  4,
#  9,
#  10,
#  4,
#  2,
#  9,
#  2,
#  2,
#  5,
#  9,
#  7,
#  7,
#  8,
#  7,
#  1,
#  8,
#  8,
#  4,
#  6,
#  2,
#  2,
#  4,
#  6,
#  5,
#  10,
#  7,
#  9,
#  9,
#  1,
#  10,
#  8,
#  1,
#  3,
#  6,
#  2,
#  5,
#  1,
#  10,
#  6,
#  6,
#  9,
#  1,
#  4,
#  9,
#  10,
#  2,
#  3,
#  5,
#  9,
#  4,
#  2,
#  1,
#  7,
#  8,
#  5,
#  2,
#  3,
#  6,
#  1,
#  5,
#  10,
#  7,
#  9,
#  3,
#  10,
#  10,
#  2,
#  1,
#  7,
#  7,
#  5,
#  8,
#  7,
#  9,
#  2,
#  5,
#  8,
#  10,
#  5,
#  8,
#  6,
#  1,
#  7,
#  ...]

# %%
# creating a new column called "rank" to assign the values from the rank list to the grouped dataframe
grouped["rank"] = rank_list
grouped = grouped[["rank"]]
grouped

#changing the grouped dataframe to a dictionary to add it to df later
rank_dict = grouped.to_dict()
# getting rid of the outer dictionary so it's not a nested dictionary and we have the values we want in the shape we want
rank_dict = rank_dict[('rank', '')]
rank_dict
# Out:
# {'A. R. Penck': 6,
#  'A.R. Penck and Frank Wollny': 4,
#  'Aaron Bobrow': 1,
#  'Aaron Fowler': 6,
#  'Aaron Garber-Maikovska': 6,
#  'Ablade Glover': 3,
#  'Aboudia': 7,
#  'Abraham Manievich': 6,
#  'Ad Dekkers': 7,
#  'Ad Reinhardt': 10,
#  'Adam Neate': 2,
#  'Adolf Fleischmann': 4,
#  'Adolph Alexander Weinman': 6,
#  'Adolph Gottlieb': 10,
#  'Adrian Ghenie': 10,
#  'Adrian Schiess': 1,
#  'Adriana Varejão': 10,
#  'Adrien Tanoux': 7,
#  'Adrien-Jean Le Mayeur de Merprès': 9,
#  'Affandi': 9,
#  'Afro': 9,
#  'After Fernand Léger': 1,
#  'After Fernando Botero': 3,
#  'After Georges Braque': 2,
#  'After Gustav Klimt': 7,
#  'After Henri Matisse': 2,
#  'After Howard Hodgkin': 1,
#  'After Pablo Picasso': 3,
#  'After Roy Lichtenstein': 2,
#  'After Yoshitomo Nara': 1,
#  'Agenore Fabbri': 3,
#  'Agnes Martin': 8,
#  'Agostino Bonalumi': 7,
#  'Agustín Cárdenas': 8,
#  'Ai Weiwei': 2,
#  'Ai Xuan': 8,
#  'Al Taylor': 3,
#  'Alain Jacquet': 6,
#  'Alan Magee': 8,
#  'Albert André': 6,
#  'Albert Bierstadt': 7,
#  'Albert Bloch': 7,
#  'Albert Marquet': 8,
#  'Albert Oehlen': 10,
#  'Alberto Burri': 10,
#  'Alberto Giacometti': 7,
#  'Alberto Gironella': 6,
#  'Alberto Magnelli': 6,
#  'Alberto di Fabio': 2,
#  'Albrecht Altdorfer': 1,
#  'Albrecht Dürer': 3,
#  'Alceo Dossena (1878-1937)': 6,
#  'Alejandro Obregón': 7,
#  'Alejandro Otero': 10,
#  'Alex Gardner': 2,
#  'Alex Hubbard': 2,
#  'Alex Katz': 9,
#  'Alexander Archipenko': 7,
#  'Alexander Borisovich Serebriakoff': 3,
#  'Alexander Calder': 10,
#  'Alexander Dmitrievich Tikhomirov': 3,
#  'Alexander Evgenievich Yakovlev': 7,
#  'Alexander Helwig Wyant': 4,
#  'Alexander Kharitonov': 5,
#  'Alexander Kosolapov': 7,
#  'Alexander May': 1,
#  'Alexander Mikhailovich Gerasimov': 10,
#  'Alexander Nikolaevich Benois': 4,
#  'Alexander Pope': 5,
#  'Alexandre Farto, aka Vhils': 6,
#  'Alexandre de Tombay': 4,
#  'Alexei Mikhailovich Gritsai': 4,
#  'Alexei Pavlovich Belykh': 3,
#  'Alexej von Jawlensky': 8,
#  'Alexis Kersey': 1,
#  'Alfonso A. Ossorio': 4,
#  'Alfred Henry Maurer': 5,
#  'Alfred Jensen': 3,
#  'Alfred Leslie': 3,
#  'Alfred Manessier': 2,
#  'Alfred Wallis': 8,
#  'Alfredo Ramos Martínez': 10,
#  'Ali Banisadr': 8,
#  'Alice Neel': 10,
#  'Alice Rahon': 7,
#  'Alicia Penalba': 5,
#  'Alighiero Boetti': 10,
#  'Alik Cavaliere': 5,
#  'Alirio Palacios': 4,
#  'Alison Watt': 4,
#  'Allen Jones': 7,
#  'Allen Jones, R.A.': 8,
#  'Allison Zuckerman': 8,
#  'Alma Berrow': 1,
#  'Amanda Ross-Ho': 4,
#  'Amedeo Modigliani': 10,
#  'Amelia Peláez': 8,
#  'Amoako Boafo': 10,
#  'Amy Sillman': 8,
#  'Ana Laura Aláez': 1,
#  'Anatoly Zverev': 2,
#  'Andreas Gursky': 10,
#  'Andrei Krisanov': 3,
#  'Andrei Molodkin': 2,
#  'Andrei Nikolaevich Bliok': 6,
#  'Andrei Roiter': 3,
#  'Andrew Brown Donaldson': 4,
#  'Andrew Wyeth': 9,
#  'André Brasilier': 8,
#  'André Butzer': 8,
#  'André Derain': 8,
#  'André Lanskoy': 7,
#  'André Lhote': 6,
#  'André Maire': 2,
#  'André Masson': 7,
#  'André Saraiva': 2,
#  'Andy Denzler': 6,
#  'Andy Warhol': 10,
#  'Ang Kiukok': 8,
#  'Angel Otero': 7,
#  'Angela Yuen': 4,
#  'Angelbert Metoyer': 6,
#  'Angki Purbandono': 1,
#  'Anh Duong': 2,
#  'Anish Kapoor': 10,
#  'Anissa Kermiche': 2,
#  'Anke Weyer': 2,
#  'Ann Craven': 5,
#  'Anna Hyatt Huntington': 5,
#  'Anna Mary Robertson (Grandma) Moses': 8,
#  'Anne Kagioka Rigoulet': 5,
#  'Anne Truitt': 7,
#  'Annette Messager': 6,
#  'Anni Albers': 2,
#  'Anselm Kiefer': 10,
#  'Anselm Reyle': 7,
#  'Anthony van Dyck': 1,
#  'Anton Maria Zanetti I': 1,
#  'Anton Raphael Mengs': 3,
#  'Anton Rooskens': 6,
#  'Antoni Clavé': 5,
#  'Antoni Piotrowski': 7,
#  'Antoni Tàpies': 9,
#  'Antonio "El Corcito" Ruiz': 5,
#  'Antonio Berni': 10,
#  'Antonio Calderara': 6,
#  'Antonio González Suárez': 1,
#  'Antonio Jacobsen': 4,
#  'Antonio Rossetti': 9,
#  'Antonio Saura': 9,
#  'Antony Gormley': 9,
#  'Antony Gormley, R.A.': 1,
#  'Antony Micallef': 4,
#  'Arcangelo Sassolino': 5,
#  'Ariamna Contino': 3,
#  'Arie Smit': 8,
#  'Aristide Caillaud': 2,
#  'Aristide Maillol': 8,
#  'Arman': 6,
#  'Armand Guillaumin': 7,
#  'Armando Morales': 8,
#  'Armando Reverón': 9,
#  'Arnaldo Pomodoro': 9,
#  'Arnaldo Roche-Rabell': 7,
#  'Arnulf Rainer': 8,
#  'Arsen Savadov': 3,
#  'Arthur Gibbons': 1,
#  'Arthur Segal': 7,
#  'Arthur Waagen': 6,
#  'Artie Vierkant': 3,
#  'Arturo Correa': 4,
#  'Arturo di Modica': 9,
#  'Asger Jorn': 6,
#  'Asher Brown Durand': 7,
#  'Asta Gröting': 1,
#  'Astrid Kirchherr': 1,
#  'Atsushi Kaga': 6,
#  'Attributed to Francesco Fanelli': 6,
#  'Attributed to Ivan Konstantinovich Aivazovsky': 4,
#  'Attributed to Raffaelle Monti (1818-1881)': 6,
#  'Attributed to Sir Thomas Lawrence, P.R.A.': 1,
#  'August Vilella': 2,
#  'Auguste Herbin': 7,
#  'Auguste Rodin': 9,
#  'Auguste Toulmouche': 6,
#  'Augusto Giacometti': 10,
#  'Austin Osman Spare': 2,
#  'Avery Singer': 9,
#  'Avigdor Arikha': 1,
#  'Ayako Rokkaku': 8,
#  'Bai Jiao': 7,
#  'Baldur Helgason': 6,
#  'Baltasar Lobo': 2,
#  'Balthus': 10,
#  'Banksy': 10,
#  'Barbara Hepworth': 9,
#  'Barbara Kruger': 9,
#  'Bari Kumar': 2,
#  'Barnett Newman': 4,
#  'Barry Flanagan, R.A.': 9,
#  'Beatrice Caracciolo': 3,
#  'Beatrice Rozenberg': 2,
#  'Beatriz Milhazes': 10,
#  'Beauford Delaney': 7,
#  'Bela de Kristo': 2,
#  'Ben Nicholson': 9,
#  'Ben Vautier': 6,
#  'Benjamin West, P.R.A.': 10,
#  'Berlinde de Bruyckere': 1,
#  'Bernar Venet': 8,
#  'Bernard Aubertin': 3,
#  'Bernard Buffet': 9,
#  'Bernard Cohen': 2,
#  'Bernard Frize': 7,
#  'Bernard Gantner': 2,
#  'Bernard Leach': 1,
#  'Bernard Meadows': 4,
#  'Bernard Réquichot': 4,
#  'Bert Hardy': 2,
#  'Beryl Cook': 4,
#  'Betty Parsons': 4,
#  'Bian Shoumin': 5,
#  'Bill Brandt': 3,
#  'Bill Viola': 1,
#  'Billy Copley': 2,
#  'Bjarne Melgaard': 5,
#  'Blake Rayne': 2,
#  'Blanche Lazzell': 4,
#  'Blinky Palermo': 7,
#  'Bo Bartlett': 8,
#  'Bob and Roberta Smith': 2,
#  'Boris Dmitrievich Grigoriev': 4,
#  'Boris Sveshnikov': 4,
#  'Boris Valentinovich Shcherbakov': 4,
#  'Bosco Sodi': 7,
#  'Bram Bogart': 3,
#  'Brian Calvin': 3,
#  'Brian Clarke': 8,
#  'Brice Marden': 10,
#  'Bridget Riley': 10,
#  'Bruce Nauman': 10,
#  'Bruno Peinado': 1,
#  'Bryan Ingham': 3,
#  'Bryan Wynter': 5,
#  'Burgoyne Diller': 7,
#  'Burt Glinn': 2,
#  'Byron Browne': 2,
#  'Cai Guo-Qiang': 9,
#  'Caio Fonseca': 4,
#  'Camille Bombois': 4,
#  'Camille Bryen': 1,
#  'Camille Pissarro': 10,
#  'Carel Visser': 2,
#  'Carl Andre': 9,
#  'Carl Buchheister': 1,
#  'Carl Ethan Akeley': 7,
#  'Carl Holty': 5,
#  'Carl Johann Spielter': 7,
#  'Carla Accardi': 3,
#  'Carlos Alfonzo': 9,
#  'Carlos Amorales': 2,
#  'Carlos Cruz-Diez': 9,
#  'Carlos Mérida': 7,
#  'Carlos Nadal': 4,
#  'Carmelo Niño': 3,
#  'Carol Rama': 7,
#  'Cecily Brown': 10,
#  'Ceri Richards': 3,
#  'Charles Camoin': 5,
#  'Charles Collins': 3,
#  'Charles Ephraim Burchfield': 7,
#  'Charles Fazzino': 1,
#  'Charles François Grenier de Lacroix, called Lacroix de Marseille': 8,
#  'Charles Ginner, A.R.A.': 4,
#  'Charles Green Shaw': 6,
#  'Charles Hossein Zenderoudi': 8,
#  'Charles Sheeler': 10,
#  'Charles Shireff': 1,
#  'Charles White': 10,
#  'Charles-Francois Grenier de Lacroix, called Lacroix de Marseille': 6,
#  'Chen Banding': 3,
#  'Chen Baochen': 3,
#  'Chen Hengke': 5,
#  'Chen Jiayan': 8,
#  'Chen Rong': 3,
#  'Chen Shaomei': 8,
#  'Chen Tai-hua (ATI)': 3,
#  'Chen Ting-shih': 8,
#  'Chen Wen Hsi': 9,
#  'Chen Wenbo': 4,
#  'Chen Zengshou': 5,
#  'Chiharu Shiota': 7,
#  'Chiho Aoshima': 3,
#  'Childe Hassam': 10,
#  'Chris Killip': 2,
#  'Chris Levine': 3,
#  'Chris Ofili': 10,
#  'Chris Smith': 7,
#  'Christian Berentz': 6,
#  'Christine Ay Tjoe': 9,
#  'Christo': 9,
#  'Christo Vladimirov Javacheff': 2,
#  'Christo and Jeanne-Claude': 6,
#  'Christoph Ruckhäberle': 3,
#  'Christopher Richard Wynne Nevinson, A.R.A.': 8,
#  'Christopher Wilmarth': 6,
#  'Christopher Wood': 8,
#  'Christopher Wool': 10,
#  'Chu Teh-Chun': 10,
#  'Chuang Che': 8,
#  'Chuck Close': 5,
#  'Chung Sanghwa': 8,
#  'Chéri Cherin': 2,
#  'Ciliana Villegas': 4,
#  'Cindy Sherman': 8,
#  'Cinga Samson': 8,
#  'Circle of Antonio Bottinelli': 8,
#  'Claes Oldenburg': 2,
#  'Claire Tabouret': 9,
#  'Claude Monet': 10,
#  'Claude Venard': 4,
#  'Claude Viallat': 6,
#  'Claude-Emile Schuffenecker': 5,
#  'Clet Abraham': 1,
#  'Clyfford Still': 10,
#  'Colin Jones': 1,
#  'Colin Self': 2,
#  'Conrad Marca-Relli': 6,
#  'Cordelia Urueta': 3,
#  'Corneille': 6,
#  'Cornelia Parker': 3,
#  'Cornelis Troost': 8,
#  'Cornelius Quabeck': 1,
#  'Cory Arcangel': 4,
#  'Cristina BanBan': 4,
#  'Cristofano Robetta': 1,
#  'Cui Jie': 7,
#  'Cundo Bermúdez': 7,
#  'Cy Gavin': 8,
#  'Cy Twombly': 10,
#  'Cândido Portinari': 10,
#  'César': 7,
#  'D*Face': 4,
#  'Da Chongguang': 6,
#  'Dado': 4,
#  'Dahlov Zorach Ipcar': 5,
#  'Daido Moriyama': 2,
#  'Dame Elisabeth Frink, R.A.': 7,
#  'Dame Lucie Rie': 1,
#  'Dame Magdalene Odundo': 8,
#  'Damien Hirst': 9,
#  'Dan Christensen': 4,
#  'Dan Colen': 7,
#  'Dan Dailey': 1,
#  'Dana Frankfort': 2,
#  'Dana Schutz': 10,
#  'Dang Xuan Hoa': 4,
#  'Daniel Arsham': 3,
#  'Davd Hockney': 6,
#  'David Alfaro Siqueiros': 9,
#  'David Batchelor': 1,
#  'David Bomberg': 8,
#  'David Bowes': 1,
#  'David Budd': 1,
#  'David Chan': 3,
#  'David Davidovich Burliuk': 8,
#  'David Hockney': 10,
#  'David Hockney, R.A.': 5,
#  'David Johnson': 5,
#  'David Jones': 4,
#  'David Kim Whittaker': 7,
#  'David LaChapelle': 6,
#  'David Loggan': 1,
#  'David Ostrowski': 3,
#  'David Reed': 3,
#  'David Roberts, R.A.': 1,
#  'David Shrigley': 2,
#  'David Smith': 10,
#  'Davis Cone': 6,
#  'Dean Cornwell': 4,
#  'Deborah Butterfield': 8,
#  'Deng Erya': 4,
#  'Deng Fen': 7,
#  'Denis Mitchell': 5,
#  'Derek Paul Boyle': 1,
#  'Derrick Adams': 2,
#  'Dexter Dalwood': 7,
#  'Diana Al-Hadid': 6,
#  'Diego Rivera': 10,
#  'Dieter Roth': 3,
#  'Ding Yanyong': 5,
#  'Ding Yi': 9,
#  'Dirck Volckertsz. Coornhert': 1,
#  'Dirk Herman Willem Filarski': 2,
#  'Dirk Skreber': 3,
#  'Dirk Vellert': 3,
#  'Dmitri Innokentievich Berezovsky': 1,
#  'Dmitri Krasnopevtsev': 7,
#  'Dmitri Plavinsky': 7,
#  'Dmitrii Shorin': 5,
#  'Dmitry Prigov': 4,
#  'Domenico Gnoli': 8,
#  'Domingo Ramos': 4,
#  'Dominique Grisor': 2,
#  'Donald Baechler': 5,
#  'Donald Hamilton Fraser, R.A.': 3,
#  'Donald Judd': 10,
#  'Donald Sultan': 3,
#  'Dong Shouping': 3,
#  'Dorothea Tanning': 9,
#  'Dorothy Brett': 6,
#  'Douglas Swan': 2,
#  'Dr. Scribble (Mr. Doodle)': 6,
#  'Duffy': 1,
#  'Duilio Barnabè': 3,
#  'Duncan Grant': 6,
#  'Dwight William Tryon': 3,
#  'Dylan Lewis': 2,
#  'Dylan Lynch': 2,
#  'Eastman Johnson': 6,
#  'Ed Ruscha': 10,
#  'Eddie Kang': 4,
#  'Eddie Martinez': 8,
#  'Edgar Degas': 10,
#  'Edgar Negret': 8,
#  'Edgar Plans': 4,
#  'Edmund de Waal': 1,
#  'Edouard Vuillard': 8,
#  'Eduard Gorokhovsky': 5,
#  'Eduard Steinberg': 4,
#  'Eduardo Chillida': 9,
#  'Eduardo Ramírez Villamizar': 6,
#  'Eduardo Terrazas': 8,
#  'Edvard Munch': 3,
#  'Edward Bawden, R.A.': 3,
#  'Edward Bekkerman': 7,
#  'Edward Burra': 10,
#  'Edward Kienholz': 5,
#  'Edward Matthew Ward R.A.': 8,
#  'Edward Mitchell Bannister': 8,
#  'Edward Moran': 7,
#  'Efrem Pavlovich Svetlichny': 3,
#  'Egon Schiele': 10,
#  'Elaine de Kooning': 5,
#  'Elizabeth Catlett': 8,
#  'Elizabeth Peyton': 10,
#  'Elliott Hundley': 6,
#  'Ellsworth Kelly': 5,
#  'Emil Fuchs': 1,
#  'Emil Nolde': 10,
#  'Emilio Isgrò': 4,
#  'Emilio Scanavino': 4,
#  'Emilio Sánchez': 5,
#  'Emilio Vedova': 4,
#  'Emily Mae Smith': 6,
#  'Emily Young': 7,
#  'Emmanuel Cooper': 1,
#  'En Iwamura': 2,
#  'Enoc Perez': 6,
#  'Enrico Castellani': 10,
#  'Enzo Cucchi': 4,
#  'Enzo Mari': 4,
#  'Eric Doeringer': 1,
#  'Eric Fischl': 6,
#  'Eric Sidner': 1,
#  'Erica Hestu Wahyuni': 3,
#  'Erich Heckel': 8,
#  'Erik Bulatov': 4,
#  'Erik Lindman': 2,
#  'Ernest Tino Trova': 2,
#  'Ernst Neizvestny': 1,
#  'Ernst Wilhelm Nay': 10,
#  'Erro': 6,
#  'Esaias van de Velde': 6,
#  'Esphyr Slobodkina': 5,
#  'Esteban Vicente': 7,
#  'Etel Adnan': 8,
#  'Ethan Cook': 4,
#  'Ethan Russell': 2,
#  'Ettore Spalletti': 7,
#  'Euan Uglow': 9,
#  'Eugen von Blaas': 9,
#  'Eugene Berman': 1,
#  'Eugène Boudin': 9,
#  'Eugène Leroy': 5,
#  'Everett Shinn': 2,
#  'Evgeny Gorokhovsky': 3,
#  'Evgeny Kropivnitsky': 1,
#  'Evgeny Rukhin': 4,
#  'Ewa Juszkiewicz': 7,
#  'Ewen Henderson': 2,
#  'FAILE': 4,
#  'FAKE': 4,
#  'FUTURA': 4,
#  'Fabrice Hyber': 6,
#  'Fairfield Porter': 5,
#  'Fang Lijun': 3,
#  'Fatina Kong': 3,
#  'Fausto Melotti': 7,
#  'Fausto Pirandello': 6,
#  'Fay Lansner': 2,
#  'Federico Zandomeneghi': 10,
#  'Feng Kanghou': 2,
#  'Feng Zikai': 6,
#  'Ferdinand Bol': 1,
#  'Ferdinand Georg Waldmüller': 10,
#  'Ferdinand Hodler': 9,
#  'Ferdinand de Braekeleer': 3,
#  'Fern Isabel Coppedge': 7,
#  'Fernand Léger': 10,
#  'Fernando Botero': 9,
#  'Fernando Zobel': 9,
#  'Fernando Zóbel': 10,
#  'Fernando de Szyszlo': 7,
#  'Filipp Andreevich Maliavin': 8,
#  'Flora Yukhnovich': 8,
#  'Floris Verster': 4,
#  'Frances Hodgkins': 2,
#  'Francesco Clemente': 4,
#  'Francis Bacon': 4,
#  'Francis Cotes, R.A.': 4,
#  'Francis Davison': 3,
#  'Francis Picabia': 9,
#  'Francis Towne': 7,
#  'Francisco Infante': 3,
#  'Francisco Matto': 3,
#  'Francisco Toledo': 9,
#  'Francisco Zúñiga': 5,
#  'Franco Angeli': 7,
#  'Frank Auerbach': 8,
#  'Frank Dobson, R.A.': 4,
#  'Frank Stella': 10,
#  'Franklin De Haven': 1,
#  'Frans Vervloet': 4,
#  'Frantisek Kupka': 10,
#  'František Kupka': 8,
#  'Franz Ackermann': 3,
#  'Franz Kline': 9,
#  'Franz West': 4,
#  'François Arnal': 1,
#  'François Boucher': 9,
#  'François Dufrêne': 5,
#  'François Gall': 3,
#  'François Morellet': 2,
#  'François Rouan': 2,
#  'François-Joseph Navez': 8,
#  'François-Xavier Lalanne': 9,
#  'Françoise Gilot': 5,
#  'Fred Brathwaite (Fab 5 Freddy)': 4,
#  'Fred Deux': 1,
#  'Frederic Edwin Church': 9,
#  'Frederic Remington': 9,
#  'Frederic, Lord Leighton': 7,
#  'Frederick Edward McWilliam, R.A.': 3,
#  'Frederik Vaerslev and Ståle Vold': 1,
#  'Fredrik Vaerslev': 4,
#  'Friedel Dzubas': 4,
#  'Friedensreich Hundertwasser': 9,
#  'Friedrich Kunath': 5,
#  'Fritz Bultman': 2,
#  'Fritz Glarner': 10,
#  'Fritz Winter': 4,
#  'Fu Baoshi': 10,
#  'Futura': 3,
#  'Félix Labisse': 3,
#  'Félix Vallotton': 6,
#  'Gabriel Orozco': 9,
#  'Gabriele Münter': 9,
#  'Gai Qi': 8,
#  'Gao Fenghan': 8,
#  'Gardar Eide Einarsson': 2,
#  'Gary Bunt': 4,
#  'Gary Hume': 2,
#  'Ged Quinn': 7,
#  'Gego': 10,
#  'Gelitin': 4,
#  'Gene Davis': 7,
#  'Genieve Figgis': 8,
#  'Geoffrey Clarke, R.A.': 2,
#  'Georg Baselitz': 10,
#  'Georg Dionysius Ehret': 7,
#  'George Chinnery': 1,
#  'George Chinnery (1774-1852), 1819': 2,
#  'George Chinnery (1774-1852), 1822': 1,
#  'George Chinnery (1774-1852), 1829': 1,
#  'George Chinnery (1774-1852), 1841': 2,
#  'George Chinnery (1774-1852), circa 1820': 1,
#  'George Chinnery (1774-1852), circa 1820,': 4,
#  'George Condo': 10,
#  'George Grosz': 5,
#  'George Inness': 6,
#  'George Kars': 4,
#  'George Morton-Clark': 5,
#  'George Richmond, R.A.': 1,
#  'George Rickey': 7,
#  'Georges Braque': 1,
#  'Georges Mathieu': 10,
#  'Georges Papazoff': 5,
#  'Georges Rouault': 5,
#  'Georges Valmier': 8,
#  "Georges d'Espagnat": 2,
#  "Georgia O'Keeffe": 10,
#  'Gerald Laing': 3,
#  'Gerald Scarfe': 3,
#  'Gerard Pieter Adolfs': 4,
#  'Gerhard Marcks': 7,
#  'Gerhard Richter': 10,
#  'Germaine Richier': 5,
#  'Gerrit Benner': 4,
#  'Gertrude Abercrombie': 7,
#  'Giacomo Manzù': 8,
#  'Gianfranco Baruchello': 2,
#  'Gianni Berengo Gardin': 1,
#  'Gilbert and George': 5,
#  'Giorgio Griffa': 5,
#  'Giorgio Morandi': 10,
#  'Giorgio de Chirico': 9,
#  'Giovanni Battista Tiepolo': 2,
#  'Giovanni Domenico Tiepolo': 1,
#  'Giulio Paolini': 4,
#  'Giuseppe Penone': 7,
#  'Giuseppe Spagnulo': 3,
#  'Glen Baxter': 1,
#  'Glenn Brown': 8,
#  'Glenn Ligon': 9,
#  'Glyn Philpot, R.A.': 8,
#  'Glyn Warren Philpot': 5,
#  'Godwin Champs Namuyimba': 5,
#  'Gong Xian': 10,
#  'Grace Robertson': 1,
#  'Graham Sutherland': 2,
#  'Graham Vivian Sutherland': 4,
#  'Grayson Perry, R.A.': 3,
#  'Grisha Bruskin': 3,
#  'Guan Liang': 6,
#  'Guillermo Kuitca': 8,
#  'Gunther Gerzso': 9,
#  'Gustav Klimt': 7,
#  'Gustave Cariot': 5,
#  'Gustave Courbet': 8,
#  'Gustave Courbet and Studio': 8,
#  'Gustave Keller': 3,
#  'Gustave Loiseau': 9,
#  'Gustave Singier': 3,
#  'Gustavus Hamilton': 1,
#  'Guy Carleton Wiggins': 8,
#  'Guy Pène Du Bois': 7,
#  'Gérard Deschamps': 6,
#  'Gérard Schneider': 6,
#  'Gérard Titus-Carmel': 1,
#  'Günther Förg': 9,
#  'Günther Uecker': 10,
#  'H. Claude Pissarro': 3,
#  'Haji Widayat': 7,
#  'Hajime Sorayama': 3,
#  'Hamish Mackie': 3,
#  'Han Snel': 6,
#  'Hananiah Harari': 2,
#  'Hank Willis Thomas': 5,
#  'Hannah Höch': 6,
#  'Hannah Starkey': 1,
#  'Hannes Kilian': 2,
#  'Hans Hartung': 8,
#  'Hans Hofmann': 9,
#  'Hans Sebald Beham': 1,
#  'Harland Miller': 7,
#  'Harold Ancart': 10,
#  'Harold Gilman': 4,
#  'Harriet Whitney Frishmuth': 8,
#  'He Tianjian': 10,
#  'He Xiangyu': 8,
#  'Hedda Sterne': 8,
#  'Heiner Meyer': 7,
#  'Helen Frankenthaler': 10,
#  'Helmut Newton': 3,
#  'Hendra Gunawan': 10,
#  'Hendrick Goltzius': 2,
#  'Henk Peeters': 5,
#  'Henri Chen KeZhan': 3,
#  'Henri Gaudier-Brzeska': 1,
#  'Henri Gervex': 10,
#  'Henri Hayden': 3,
#  'Henri Le Sidaner': 9,
#  'Henri Martin': 9,
#  'Henri Matisse': 10,
#  'Henri Michaux': 3,
#  'Henri Mège': 4,
#  'Henri de Toulouse-Lautrec': 5,
#  'Henri-Edmond Cross': 5,
#  'Henry Chalfant': 1,
#  'Henry Darger': 10,
#  'Henry Hudson': 7,
#  'Henry Korda': 2,
#  'Henry Moore': 10,
#  'Henry Moret': 9,
#  'Henry Mundy': 2,
#  "Henry Nelson O'Neil, A.R.A.": 6,
#  'Henry Taylor': 9,
#  'Herbert Zangs': 5,
#  'Herman Herzog': 2,
#  'Herman Saftleven': 5,
#  'Hernan Bas': 7,
#  'Hervé Télémaque': 5,
#  'Hew Locke': 4,
#  'Hideaki Kawashima': 3,
#  'Hikari Shimoda': 1,
#  'Hilary Pecis': 8,
#  'Hiram Maristany': 3,
#  'Hiroshi Sugimoto': 8,
#  'Hisao Domoto': 7,
#  'Ho Kan': 7,
#  'Honoré Daumier': 8,
#  'Horace Hone, A.R.A.': 1,
#  'Howard Hodgkin': 2,
#  'Hsiao Chin': 8,
#  'Hu Peiheng': 1,
#  'Hua Yan': 7,
#  'Huang Daozhou': 9,
#  'Huang Jun': 5,
#  'Huang Junbi': 5,
#  'Huang Yongyu': 9,
#  'Huang Yuxing': 9,
#  'Hubert Robert': 8,
#  'Hughie Lee-Smith': 8,
#  "Hughie O'Donoghue, R.A.": 4,
#  'Hugo Wilson': 5,
#  'Hugó Scheiber': 4,
#  'Hunt Slonem': 3,
#  'Hurvin Anderson': 8,
#  'I Made Djirna': 2,
#  'INVADER': 7,
#  'Iba Ndiaye': 1,
#  'Ida Ekblad': 4,
#  'Idris Khan': 8,
#  'Igor Mitoraj': 8,
#  'Ikumi Nakada': 1,
#  'Ilya Bolotowsky': 5,
#  'Ilya Kabakov': 9,
#  'Ilya Sergeevich Glazunov': 5,
#  'Imi Knoebel': 5,
#  'Invader': 6,
#  'Iosif Evstafievich Krachkovsky': 7,
#  'Irene Rice Pereira': 1,
#  'Irma Stern': 10,
#  'Isaac Oliver': 6,
#  'Isamu Noguchi': 10,
#  'Isshaq Ismail': 4,
#  'Issy Wood': 8,
#  'Ivan Chuikov': 8,
#  'Ivan Ivanovich Godlevsky': 2,
#  'Ivan Konstantinovich Aivazovsky': 9,
#  'Ivan Morley': 1,
#  'Ivan Pavlovich Pokhitonov': 9,
#  'Ivan Puni (Jean Pougny)': 4,
#  'Ivan Turetskyy': 2,
#  'Ivon Hitchens': 8,
#  'Ivor Abrahams, R.A.': 2,
#  'Izumi Kato': 9,
#  'J. Alfonso Toft': 1,
#  'JR': 1,
#  'Jacek Malczewski': 7,
#  'Jack Tworkov': 6,
#  'Jackson Pollock': 9,
#  'Jacky Tsai': 7,
#  'Jacob van Ruisdael': 1,
#  'Jacques Bouyssou': 1,
#  'Jacques Doucet': 2,
#  'Jacques Hérold': 6,
#  'Jacques Lipchitz': 5,
#  'Jacques Martin-Ferrières': 5,
#  'Jacques Villeglé': 4,
#  'Jadé Fadojutimi': 9,
#  'Jahan Loh': 4,
#  'James Brooks': 4,
#  'James Brown': 2,
#  'James Doran-Webb': 2,
#  'James Holdsworth': 1,
#  'James Holland, O.W.S.': 1,
#  'James Rosenquist': 6,
#  'James Tissot': 10,
#  'James Tower': 4,
#  'Jamian Juliano-Villani': 8,
#  'Jammie Holmes': 7,
#  'Jan Josefsz. van Goyen': 8,
#  'Jan Kaláb': 5,
#  'Jan Lebenstein': 2,
#  'Jan Matulka': 3,
#  'Jan Symonsz. Pynas': 7,
#  'Janet Fish': 4,
#  'Jannis Kounellis': 9,
#  'Jasper Johns': 8,
#  'Javier Calleja': 6,
#  'Javier Marín': 7,
#  'Jean Alexandre Joseph Falguière': 7,
#  'Jean Bazaine': 6,
#  'Jean Carzou': 6,
#  'Jean Cortot': 3,
#  'Jean Crotti': 6,
#  'Jean Degottex': 8,
#  'Jean Dubuffet': 10,
#  'Jean Dufy': 6,
#  'Jean Fautrier': 9,
#  'Jean Hélion': 3,
#  'Jean Jacques Henner': 5,
#  'Jean Metzinger': 8,
#  'Jean Michel Folon': 3,
#  'Jean Spencer': 1,
#  'Jean Tinguely': 5,
#  'Jean-Auguste-Dominique Ingres': 8,
#  'Jean-Baptiste Bernadet': 4,
#  'Jean-Baptiste Regnault': 8,
#  'Jean-Jacques Pradier, called James': 4,
#  'Jean-Jules-Antoine Lecomte du Nouÿ': 7,
#  'Jean-Michel Atlan': 8,
#  'Jean-Michel Basquiat': 10,
#  'Jean-Paul Riopelle': 9,
#  'Jean-Pierre Cassigneul': 5,
#  'Jean-Pierre Pincemin': 7,
#  'Jean-Pierre Yvaral': 2,
#  'Jedd Garet': 1,
#  'Jeff Elrod': 8,
#  'Jeff Koons': 10,
#  'Jeff Sonhouse': 7,
#  'Jennifer Guidi': 9,
#  'Jerkface': 2,
#  'Jesse Mockrin': 5,
#  'Jessica Rankin': 4,
#  'Jesús Rafael Soto': 10,
#  'Jia Aili': 10,
#  'Jill Mulleady': 9,
#  'Jim Dine': 4,
#  'Jim McHugh': 1,
#  'Jimmie Durham': 2,
#  'Jin Cheng; Zhou Zi': 6,
#  'Jiri Georg Dokoupil': 4,
#  'Jo Niemeyer': 3,
#  'Joan Cornellà': 3,
#  'Joan Miró': 10,
#  'Joan Mitchell': 10,
#  'Joaquin Sorolla y Bastida': 10,
#  'Joe Bradley': 9,
#  'Joel Mesler': 8,
#  'Joel Shapiro': 9,
#  'Johannes Hendrik Eversen': 3,
#  'Johannes Hermanus Barend Koekkoek': 7,
#  'John Armleder': 5,
#  'John Atkinson Grimshaw': 8,
#  'John Bacon (1740-1799)': 6,
#  'John Baldessari': 1,
#  'John Bratby, R.A.': 3,
#  'John Brett, A.R.A.': 3,
#  'John C. Kacere': 5,
#  'John Chamberlain': 9,
#  'John Chilver': 1,
#  'John Cox Dillman Engleheart': 1,
#  'John Currin': 7,
#  'John Downman, A.R.A.': 1,
#  'John Dugdale': 1,
#  'John F. Clymer': 8,
#  'John Gilroy': 4,
#  'John Hamilton Mortimer, A.R.A.': 4,
#  'John Harrison Levee': 4,
#  'John Hoyland, R.A.': 6,
#  'John James Audubon': 8,
#  'John Keane': 3,
#  'John Kørner': 3,
#  'John Linnell': 4,
#  'John Marin': 6,
#  'John McCracken': 9,
#  'John McLaughlin': 9,
#  'John Middleton': 2,
#  'John Minton': 7,
#  'John Opie, R.A.': 3,
#  'John Piper': 5,
#  'John Rogers Herbert': 1,
#  'John Russell': 4,
#  'John Smart': 1,
#  'John Smart, Junior': 1,
#  'John Taylor': 2,
#  'John Thomas Serres': 1,
#  'John Wells': 5,
#  'John Wesley': 7,
#  'JonOne': 5,
#  'Jonas Wood': 7,
#  'Jonathan Borofsky': 4,
#  'Jonathan Knight': 3,
#  'Jonathan Lasker': 5,
#  'Jonathan Scott Hartley': 3,
#  'Jordan Wolfson': 6,
#  'Jorge de la Vega': 5,
#  'Jorinde Voigt': 6,
#  'Josef Albers': 10,
#  'Josef Theodor Hansen': 2,
#  'Joseph Beuys': 7,
#  'Joseph Cornell': 4,
#  'Joseph Edward Southall, R.W.S., R.B.S.A., N.E.A.C.': 3,
#  'Joseph Mallord William Turner, R.A.': 10,
#  'Joseph Sima': 9,
#  'Joseph Stella': 2,
#  'Josh Kolbo': 1,
#  'Josh Smith': 5,
#  'Josh Sperling': 7,
#  'Josh Sperling x Sam Friedman': 5,
#  'Josias Barbette': 1,
#  'José Clemente Orozco': 1,
#  'José María Sicilia': 3,
#  'José Parlá': 7,
#  'Joy Labinjo': 5,
#  'Joyce Pensato': 5,
#  'Juan Muñoz': 9,
#  "Juan O'Gorman": 9,
#  'Juan Sánchez': 6,
#  'Juan Uslé': 6,
#  'Juana Francés': 5,
#  'Judy Chicago': 3,
#  'Jules Olitski': 6,
#  'Julian Onderdonk': 8,
#  'Julian Opie': 4,
#  'Julian Schnabel': 9,
#  'Julie Curtiss': 10,
#  'Julie Hart Beers': 4,
#  'Julie Roberts': 2,
#  'Julien-Charles Dubois': 9,
#  'Julio Ruelas': 2,
#  'Julius Bissier': 2,
#  'Justin Roiland': 5,
#  'Jörg Immendorff': 9,
#  'KAWS': 7,
#  'Kang Youwei': 7,
#  'Karel Appel': 8,
#  'Karin Kneffel': 7,
#  'Karina Ami': 1,
#  'Karl Albert Buehr': 8,
#  'Karl Hofer': 8,
#  'Karl Holmqvist': 4,
#  'Karl Schmidt-Rottluff': 6,
#  'Kasing Lung': 2,
#  'Kate Brinkworth': 2,
#  'Katharina Grosse': 4,
#  'Katherine Bernhardt': 6,
#  'Katherine Bradford': 5,
#  'Kazuo Shiraga': 10,
#  'Kazuya Sakai': 7,
#  'Kees van Dongen': 9,
#  'Kehinde Wiley': 9,
#  'Keisuke Maeda': 1,
#  'Keith Haring': 10,
#  'Keith Haring and Bill Waterson': 8,
#  'Keith Richardson-Jones': 1,
#  'Keith Tyson': 3,
#  'Keith Vaughan': 6,
#  'Ken Price': 2,
#  'Kenneth Armitage, R.A.': 5,
#  'Kenneth Martin': 1,
#  'Kenneth Noland': 10,
#  'Kenneth Southworth Davies': 6,
#  'Kenny Scharf': 6,
#  'Kerry James Marshall': 9,
#  'Kevin Berlin': 1,
#  'Key Sato': 4,
#  'Kiki Smith': 9,
#  'Kim Whanki': 10,
#  'Kiran Telkar': 2,
#  'Klara Lidén': 3,
#  'Koichi Sato': 5,
#  'Konstantin Ivanovich Gorbatov': 9,
#  'Korakrit Arunanondchai': 4,
#  'Kuo Yenfu': 2,
#  'Kura Shomali': 1,
#  'Kurt Schwitters': 7,
#  'Kusama Yayoi': 8,
#  'Kwon Ki-Soo': 5,
#  'Kyle Thurman': 2,
#  'Kyne': 3,
#  'Käthe Kollwitz': 6,
#  'Ladi Kwali': 1,
#  'Lady Pink': 5,
#  'Lalan': 10,
#  'Larry Poons': 7,
#  'Larry Rivers': 9,
#  'Laslett John Pott': 3,
#  'Laura Owens': 10,
#  'Laurence Stephen Lowry, R.A.': 10,
#  'Lawrence Calcagno': 2,
#  'Lawrence Hilliard': 1,
#  'Lawrence Weiner': 7,
#  'Le Pho': 7,
#  'Lee Bul': 5,
#  'Lee Man Fong': 8,
#  'Lee Quiñones': 7,
#  'Lee Ufan': 9,
#  'Leigh Ledare': 2,
#  'Leo Gestel': 5,
#  'Leon Gaspard': 8,
#  'Leon Kossoff': 10,
#  'Leon Kroll': 5,
#  'Leon Polk Smith': 8,
#  'Leon Tarasewicz': 6,
#  'Leon Underwood': 1,
#  'Leonardo Cremonini': 7,
#  ...}

# %%
# using the map function to assign the values from the rank_dict to a new column called "artist_rank"
df["artist_rank"] = df['artist_name'].map(rank_dict)

# inspecting the distribution of ranks
df["artist_rank"].value_counts()
# Out:
# artist_rank
# 10    851
# 9     511
# 7     446
# 8     430
# 4     352
# 1     348
# 5     336
# 6     304
# 2     291
# 3     289
# Name: count, dtype: int64

# %%
# inspecting the distribution of artists
df["artist_name"].value_counts()
# Out:
# artist_name
# Shepard Fairey                        111
# Pablo Picasso                          93
# Andy Warhol                            66
# Takashi Murakami                       54
# KAWS                                   50
#                                      ...
# Philip Alexius de László, P.R.B.A.      1
# Robert Walker Macbeth, R.A.             1
# Jacek Malczewski                        1
# Antoni Piotrowski                       1
# Hugo Wilson                             1
# Name: count, Length: 1776, dtype: int64

# %%
# checking to see if all columns are present that we want to have
df
# Out:
#            artist_name  year_artist_born   age  length  width  height  \
# 0           Etel Adnan            1925.0  96.0    81.0   65.0     1.0
# 1         Hilary Pecis            1979.0  42.0   106.9   76.3     1.0
# 2         Avery Singer            1987.0  34.0    76.2   98.5     1.0
# 3     Flora Yukhnovich            1990.0  31.0   169.5  220.0     1.0
# 4          Salman Toor            1983.0  38.0    99.5   80.0     1.0
# ...                ...               ...   ...     ...    ...     ...
# 4153         Fred Deux            1924.0  91.0    59.5   83.0     1.0
# 4154         Fred Deux            1924.0  91.0    71.0  101.0     1.0
# 4155         Fred Deux            1924.0  91.0    73.0  102.0     1.0
# 4156         Fred Deux            1924.0  91.0    46.5   17.5     1.0
# 4157         Fred Deux            1924.0  91.0    30.0   47.5     1.0
#
#       year_of_work  age_at_work  lower_est_USD  upper_est_USD  sold_in_USD  \
# 0           1973.0         48.0       74930.94       99907.92    440593.93
# 1           2019.0         40.0       62442.45       87419.43    251767.96
# 2           2016.0         29.0      187327.35      249769.80    314709.95
# 3           2020.0         30.0       74930.94       99907.92   2814281.22
# 4           2018.0         35.0      124884.90      187327.35    361916.44
# ...            ...          ...            ...            ...          ...
# 4153        1960.0         36.0         857.52        1286.28      6752.97
# 4154        1959.0         35.0        1071.90        2143.80      4727.08
# 4155        1959.0         35.0        1071.90        2143.80      6752.97
# 4156        1959.0         35.0        1607.85        2143.80      5672.49
# 4157        1959.0         35.0        2143.80        3215.70      6752.97
#
#       Material_Category  act_area  posthumous_combined  average_est_USD  \
# 0                     1   5265.00                    0        87419.430
# 1                     1   8156.47                    0        74930.940
# 2                     1   7505.70                    0       218548.575
# 3                     1  37290.00                    0        87419.430
# 4                     1   7960.00                    0       156106.125
# ...                 ...       ...                  ...              ...
# 4153                  7   4938.50                    1         1071.900
# 4154                  7   7171.00                    1         1607.850
# 4155                  7   7446.00                    1         1607.850
# 4156                 10    813.75                    1         1875.825
# 4157                 10   1425.00                    1         2679.750
#
#       artist_rank
# 0               8
# 1               8
# 2               9
# 3               8
# 4               9
# ...           ...
# 4153            1
# 4154            1
# 4155            1
# 4156            1
# 4157            1
#
# [4158 rows x 16 columns]

# %%
# dropping the columns "average_est_USD" and "artist_name" since they fulfilled their purpose and will not be part of the ML model
df = df.drop(columns=["average_est_USD", "artist_name"])
df
# Out:
#       year_artist_born   age  length  width  height  year_of_work  \
# 0               1925.0  96.0    81.0   65.0     1.0        1973.0
# 1               1979.0  42.0   106.9   76.3     1.0        2019.0
# 2               1987.0  34.0    76.2   98.5     1.0        2016.0
# 3               1990.0  31.0   169.5  220.0     1.0        2020.0
# 4               1983.0  38.0    99.5   80.0     1.0        2018.0
# ...                ...   ...     ...    ...     ...           ...
# 4153            1924.0  91.0    59.5   83.0     1.0        1960.0
# 4154            1924.0  91.0    71.0  101.0     1.0        1959.0
# 4155            1924.0  91.0    73.0  102.0     1.0        1959.0
# 4156            1924.0  91.0    46.5   17.5     1.0        1959.0
# 4157            1924.0  91.0    30.0   47.5     1.0        1959.0
#
#       age_at_work  lower_est_USD  upper_est_USD  sold_in_USD  \
# 0            48.0       74930.94       99907.92    440593.93
# 1            40.0       62442.45       87419.43    251767.96
# 2            29.0      187327.35      249769.80    314709.95
# 3            30.0       74930.94       99907.92   2814281.22
# 4            35.0      124884.90      187327.35    361916.44
# ...           ...            ...            ...          ...
# 4153         36.0         857.52        1286.28      6752.97
# 4154         35.0        1071.90        2143.80      4727.08
# 4155         35.0        1071.90        2143.80      6752.97
# 4156         35.0        1607.85        2143.80      5672.49
# 4157         35.0        2143.80        3215.70      6752.97
#
#       Material_Category  act_area  posthumous_combined  artist_rank
# 0                     1   5265.00                    0            8
# 1                     1   8156.47                    0            8
# 2                     1   7505.70                    0            9
# 3                     1  37290.00                    0            8
# 4                     1   7960.00                    0            9
# ...                 ...       ...                  ...          ...
# 4153                  7   4938.50                    1            1
# 4154                  7   7171.00                    1            1
# 4155                  7   7446.00                    1            1
# 4156                 10    813.75                    1            1
# 4157                 10   1425.00                    1            1
#
# [4158 rows x 14 columns]

# %%
# defining which columns we want to change from floats to integers
float_to_int = ['year_artist_born', 'age', 'year_of_work', "age_at_work"]
# changing the desired columns to integers 
df[float_to_int] = df[float_to_int].astype(int)
df
# Out:
#       year_artist_born  age  length  width  height  year_of_work  age_at_work  \
# 0                 1925   96    81.0   65.0     1.0          1973           48
# 1                 1979   42   106.9   76.3     1.0          2019           40
# 2                 1987   34    76.2   98.5     1.0          2016           29
# 3                 1990   31   169.5  220.0     1.0          2020           30
# 4                 1983   38    99.5   80.0     1.0          2018           35
# ...                ...  ...     ...    ...     ...           ...          ...
# 4153              1924   91    59.5   83.0     1.0          1960           36
# 4154              1924   91    71.0  101.0     1.0          1959           35
# 4155              1924   91    73.0  102.0     1.0          1959           35
# 4156              1924   91    46.5   17.5     1.0          1959           35
# 4157              1924   91    30.0   47.5     1.0          1959           35
#
#       lower_est_USD  upper_est_USD  sold_in_USD  Material_Category  act_area  \
# 0          74930.94       99907.92    440593.93                  1   5265.00
# 1          62442.45       87419.43    251767.96                  1   8156.47
# 2         187327.35      249769.80    314709.95                  1   7505.70
# 3          74930.94       99907.92   2814281.22                  1  37290.00
# 4         124884.90      187327.35    361916.44                  1   7960.00
# ...             ...            ...          ...                ...       ...
# 4153         857.52        1286.28      6752.97                  7   4938.50
# 4154        1071.90        2143.80      4727.08                  7   7171.00
# 4155        1071.90        2143.80      6752.97                  7   7446.00
# 4156        1607.85        2143.80      5672.49                 10    813.75
# 4157        2143.80        3215.70      6752.97                 10   1425.00
#
#       posthumous_combined  artist_rank
# 0                       0            8
# 1                       0            8
# 2                       0            9
# 3                       0            8
# 4                       0            9
# ...                   ...          ...
# 4153                    1            1
# 4154                    1            1
# 4155                    1            1
# 4156                    1            1
# 4157                    1            1
#
# [4158 rows x 14 columns]

# %%
# now for the comparison of different models to see which one is best for our purpose we import the models
# in addition we import train_test_split to split the data easily into training and test data
# and some metrics to evaluate how well our models did plus the matplotlib library for plotting our results
# this is probably a good point to mention that I know these models from prior courses (Business Analytics / Machine Learning & DSF)

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt


# defining our variables (X) and target value (y)
X = df.drop(columns="sold_in_USD")
y = df["sold_in_USD"]

# splitting the data into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


# initializing our models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
}
# ChatGPT gave me the idea to combine the models in a list and let it run through a loop for a more efficient comparison 
# instead of trying each model out one after the other


# creating a template for our results
results = {"Model": [], "RMSE": [], "R^2": []}

# creating a loop for training and evaluating the models
for name, model in models.items():
    # training the model on the training data
    model.fit(X_train, y_train)

    # using the trained model to give a prediction on the testing data
    y_pred = model.predict(X_test)

    # using our performance metrics rmse (root mean squared error) and r^2 (seeing what amoun)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)

    # saving our results in our template
    results["Model"].append(name)
    results["RMSE"].append(rmse)
    results["R^2"].append(r2)

# creating a df out of our results template
results_df = pd.DataFrame(results)

# showing the df
print(results_df)

# creating a plot
fig, ax = plt.subplots()
# making it bar chart
ax.bar(results_df["Model"], results_df["R^2"], color="green", alpha=0.7)
# setting a title and labels for the x and y axis
ax.set_title("Model Comparison")
ax.set_xlabel("Model")
ax.set_ylabel("R^2")

plt.show()
# Out:
#                Model           RMSE       R^2
# 0  Linear Regression  784416.162220  0.873317
# 1      Random Forest  605607.688950  0.924490
# 2  Gradient Boosting  614814.611477  0.922176

# %%
# now that we know that the random forest and gradient boosting model perform both quite close to each other
# we chose the random forest model for the streamlit prediction because it performs almost as well as gradient boosting
# but random forest loads quicker and is considered a more robust model

# defining our variables (X) and target value (y)
X = df.drop(columns="sold_in_USD")
y = df["sold_in_USD"]

# splitting the data into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# establishing a Random Forest model and training it on the training data
model = RandomForestRegressor()
model.fit(X_train, y_train)

# using the trained model to give a prediction on the testing data
y_pred = model.predict(X_test)

# STREAMLIT TEAM from here one the integration is yours

# %%
# now to visualize the success of our model we are visualizing it

# finding the min and max value between the actual values and our prediction 
min_value=np.array([y_test.min(), y_pred.min()]).min()
max_value=np.array([y_test.max(), y_pred.max()]).max()

# creating a scatter plot to show the relationship between our predicted and actual values
# and creating a line to separate the sphere of actual values from the sphere of the predicted values
fig, ax = plt.subplots()
ax.scatter(y_test,y_pred, color="blue", alpha=0.2)
ax.plot([min_value,max_value], [min_value, max_value], lw=1, color="green")

# setting title and axis labels
ax.set_title("Actual vs Predicted Values")
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')

plt.show()

# %%
# changing the code for the plot to shrink the window of values that we see since most values seem to be < 500 000
# the idea to use a limit parameter came from ChatGPT, as well as the use of .set_xlim and .set_ylim

def actual_vs_predicted_plot(y_true, y_pred, limit):

    # finding the min and max value between the actual values and our prediction
    min_value = np.array([y_true.min(), y_pred.min()]).min()
    max_value = np.array([y_true.max(), y_pred.max()]).max()

    # defining the limit and min_value by making sure that the limit is not bigger than the max value or smaller than the min value
    limit = min(limit, max_value) 
    min_value = min(min_value, limit)
    
    # creating a scatter plot and a line to visualize our performance
    fig, ax = plt.subplots()
    ax.scatter(y_true, y_pred, color="blue", alpha=0.2)
    ax.plot([min_value, limit], [min_value, limit], lw=1, color="green")

    # setting title and axis labels
    ax.set_title("Actual vs Predicted Values")
    ax.set_xlabel('Actual')
    ax.set_ylabel('Predicted')

    # setting the x and y axis limits
    ax.set_xlim([min_value, limit])
    ax.set_ylim([min_value, limit])

    plt.show()

# %%
# the plot for values up to 500 000
actual_vs_predicted_plot(y_test, y_pred, limit=500000)

# %%
# the plot for values up to 100 000
actual_vs_predicted_plot(y_test, y_pred, limit=100000)

# %%
# the plot for values up to 20 000
actual_vs_predicted_plot(y_test, y_pred, limit=20000)
